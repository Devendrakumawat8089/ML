# %% [markdown]
# # Phase 1: Data Collection & Understanding

# %% [markdown]
# 1. Load the dataset.
# 2. Display the first 10 records.
# 3. Display the last 10 records.
# 4. Check the shape of the dataset.
# 5. Display all column names.
# 6. Check data types of all columns.
# 7. Generate summary statistics.
# 8. Identify:
# Numerical Features
# Categorical Features

# %%
import pandas as pd
df = pd.read_csv('googleplaystore.csv')

# %%
df.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
# 5     167  5.6M      50,000+  Free     0       Everyone
# 6     178   19M      50,000+  Free     0       Everyone
# 7   36815   29M   1,000,000+  Free     0       Everyone
# 8   13791   33M   1,000,000+  Free     0       Everyone
# 9     121  3.1M      10,000+  Free     0       Everyone
#
#                       Genres        Last Updated         Current Ver  \
# 0               Art & Design     January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play    January 15, 2018               2.0.0
# 2               Art & Design      August 1, 2018               1.2.4
# 3               Art & Design        June 8, 2018  Varies with device
# 4    Art & Design;Creativity       June 20, 2018                 1.1
# 5               Art & Design      March 26, 2017                 1.0
# 6               Art & Design      April 26, 2018                 1.1
# 7               Art & Design       June 14, 2018            6.1.61.1
# 8               Art & Design  September 20, 2017               2.9.2
# 9    Art & Design;Creativity        July 3, 2018                 2.8
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up
# 5    2.3 and up
# 6  4.0.3 and up
# 7    4.2 and up
# 8    3.0 and up
# 9  4.0.3 and up

# %%
df.tail(10)
# Out:
#                                                  App             Category  \
# 10831                       payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10832                                       FR Tides              WEATHER
# 10833                                    Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                  FR Calculator               FAMILY
# 10835                                       FR Forms             BUSINESS
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10831     NaN      38                9.8M       5,000+  Free     0
# 10832     3.8    1195                582k     100,000+  Free     0
# 10833     4.8      44                619k       1,000+  Free     0
# 10834     4.0       7                2.6M         500+  Free     0
# 10835     NaN       0                9.6M          10+  Free     0
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres        Last Updated  \
# 10831       Everyone  Maps & Navigation       June 13, 2018
# 10832       Everyone            Weather   February 16, 2014
# 10833       Everyone  Books & Reference      March 23, 2014
# 10834       Everyone          Education       June 18, 2017
# 10835       Everyone           Business  September 29, 2016
# 10836       Everyone          Education       July 25, 2017
# 10837       Everyone          Education        July 6, 2018
# 10838       Everyone            Medical    January 20, 2017
# 10839     Mature 17+  Books & Reference    January 19, 2015
# 10840       Everyone          Lifestyle       July 25, 2018
#
#               Current Ver         Android Ver
# 10831           2.0.148.0          4.0 and up
# 10832                 6.0          2.1 and up
# 10833                 0.8          2.2 and up
# 10834               1.0.0          4.1 and up
# 10835               1.1.5          4.0 and up
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  str
#  1   Category        10841 non-null  str
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  str
#  4   Size            10841 non-null  str
#  5   Installs        10841 non-null  str
#  6   Type            10840 non-null  str
#  7   Price           10841 non-null  str
#  8   Content Rating  10840 non-null  str
#  9   Genres          10841 non-null  str
#  10  Last Updated    10841 non-null  str
#  11  Current Ver     10833 non-null  str
#  12  Android Ver     10838 non-null  str
# dtypes: float64(1), str(12)
# memory usage: 1.1 MB

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
num_col = df.select_dtypes(include = ['float64' , 'int64']).columns

# %%
num_col
# Out:
# Index(['Rating'], dtype='str')

# %%
cat_col = df.select_dtypes(include = [ 'object']).columns
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6520\3227314087.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_col = df.select_dtypes(include = [ 'object']).columns

# %%
cat_col
# Out:
# Index(['App', 'Category', 'Reviews', 'Size', 'Installs', 'Type', 'Price',
#        'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='str')

# %% [markdown]
#  1. How many rows and columns are present?

# %%
df.shape # 10841 rows and 13 Columns
# Out:
# (10841, 13)

# %% [markdown]
#  2. Which feature has the highest number of unique values?

# %%
df.nunique().idxmax() # ('App' : 9660)
# Out:
# 'App'

# %% [markdown]
#  3. Which column may act as an identifier?

# %%
# 4. Which columns appear to need cleaning?

# %% [markdown]
# # Phase 2: Data Quality Assessment

# %% [markdown]
# 1. Check for duplicate records.
# 2. Count duplicate rows.
# 3. Remove duplicate rows.
# 4. Verify the dataset shape after removing duplicates

# %%
print(df.duplicated().sum())
# Out:
# 483

# %%
df =df.drop_duplicates()

# %%
df.shape
# Out:
# (10358, 13)

# %%
# 1. How many duplicate records were found?
# 2. Why should duplicate records be removed before model building?
# 3. What problems can duplicate data create?

# %% [markdown]
# # Phase 3: Data Type Correction

# %% [markdown]
# The following columns are stored as text:
# * Installs
# * Price
# * Size
# * Reviews

# %%
df[['Installs' , 'Price','Size','Reviews']]
# Out:
#           Installs Price                Size Reviews
# 0          10,000+     0                 19M     159
# 1         500,000+     0                 14M     967
# 2       5,000,000+     0                8.7M   87510
# 3      50,000,000+     0                 25M  215644
# 4         100,000+     0                2.8M     967
# ...            ...   ...                 ...     ...
# 10836       5,000+     0                 53M      38
# 10837         100+     0                3.6M       4
# 10838       1,000+     0                9.5M       3
# 10839       1,000+     0  Varies with device     114
# 10840  10,000,000+     0                 19M  398307
#
# [10358 rows x 4 columns]

# %%
df['Installs'] = df['Installs'].str.replace('+','').str.replace(',','')

# %%
df['Installs'] = df['Installs'].map({'Free':'0'})

# %%
# df['Installs'].astype('int')

# %%
df['Installs'] = pd.to_numeric(df['Installs'])

# %%
df['Installs']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 10836   NaN
# 10837   NaN
# 10838   NaN
# 10839   NaN
# 10840   NaN
# Name: Installs, Length: 10358, dtype: float64

# %% [markdown]
# # Phase 4: Missing Value Treatment

# %% [markdown]
# 1. Identify missing values.
# 2. Calculate the percentage of missing values in each column.
# 3. Categorize columns based on missing value percentage

# %%
df.isnull().sum()
# Out:
# App                   0
# Category              0
# Rating             1465
# Reviews               0
# Size                  0
# Installs          10357
# Type                  1
# Price                 0
# Content Rating        1
# Genres                0
# Last Updated          0
# Current Ver           8
# Android Ver           3
# dtype: int64

# %%
df.isnull()
# Out:
#          App  Category  Rating  Reviews   Size  Installs   Type  Price  \
# 0      False     False   False    False  False      True  False  False
# 1      False     False   False    False  False      True  False  False
# 2      False     False   False    False  False      True  False  False
# 3      False     False   False    False  False      True  False  False
# 4      False     False   False    False  False      True  False  False
# ...      ...       ...     ...      ...    ...       ...    ...    ...
# 10836  False     False   False    False  False      True  False  False
# 10837  False     False   False    False  False      True  False  False
# 10838  False     False    True    False  False      True  False  False
# 10839  False     False   False    False  False      True  False  False
# 10840  False     False   False    False  False      True  False  False
#
#        Content Rating  Genres  Last Updated  Current Ver  Android Ver
# 0               False   False         False        False        False
# 1               False   False         False        False        False
# 2               False   False         False        False        False
# 3               False   False         False        False        False
# 4               False   False         False        False        False
# ...               ...     ...           ...          ...          ...
# 10836           False   False         False        False        False
# 10837           False   False         False        False        False
# 10838           False   False         False        False        False
# 10839           False   False         False        False        False
# 10840           False   False         False        False        False
#
# [10358 rows x 13 columns]

# %%
df.isnull().sum()/len(df)*100
# Out:
# App                0.000000
# Category           0.000000
# Rating            14.143657
# Reviews            0.000000
# Size               0.000000
# Installs          99.990346
# Type               0.009654
# Price              0.000000
# Content Rating     0.009654
# Genres             0.000000
# Last Updated       0.000000
# Current Ver        0.077235
# Android Ver        0.028963
# dtype: float64

# %%
for col in df.columns:

    percent = (
        df[col].isnull().sum() /
        len(df)
    ) * 100

    if percent == 0:
        category = "No Missing Values"

    elif percent < 5:
        category = "Low Missing"

    elif percent < 20:
        category = "Moderate Missing"

    else:
        category = "High Missing"

    print(f"{col}: {category}")
# Out:
# App: No Missing Values
# Category: No Missing Values
# Rating: Moderate Missing
# Reviews: No Missing Values
# Size: No Missing Values
# Installs: High Missing
# Type: Low Missing
# Price: No Missing Values
# Content Rating: Low Missing
# Genres: No Missing Values
# Last Updated: No Missing Values
# Current Ver: Low Missing
# Android Ver: Low Missing

# %%
df_mean = df.copy()

# %%
for col in num_col:

    df_mean[col].fillna(
        df_mean[col].mean(),
        inplace=True
    )
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6520\1298288549.py:3: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df_mean[col].fillna(

# %%
df_mean[num_col].isnull().sum()
# Out:
# Rating    1465
# dtype: int64

# %%
df_median = df.copy()

# %%
for col in num_col:

    df_mean[col].fillna(
        df_median[col].median(),
        inplace=True
    )
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6520\47788793.py:3: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df_mean[col].fillna(

# %%
df_mean[num_col].isnull().sum()
# Out:
# Rating    1465
# dtype: int64

# %%
print("Original Mean:",
      df['Rating'].mean())

print("Original Median:",
      df['Rating'].median())
# Out:
# Original Mean: 4.18954233666929
# Original Median: 4.3

# %%
df_mode = df.copy()

# %%
for col in cat_col:

    mode_value = df_mode[col].mode()[0]

    df_mode[col].fillna(
        mode_value,
        inplace=True
    )
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6520\1742646638.py:5: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df_mode[col].fillna(

# %%
df_mode[cat_col].isnull().sum()
# Out:
# App                   0
# Category              0
# Reviews               0
# Size                  0
# Installs          10357
# Type                  1
# Price                 0
# Content Rating        1
# Genres                0
# Last Updated          0
# Current Ver           8
# Android Ver           3
# dtype: int64

# %%
df_constant = df.copy()

# %%
# for col in cat_col:

#     df_constant[col].fillna(
#         'Unknown',
#         inplace=True
#     )

# %%
df_constant[cat_col].isnull().sum()
# Out:
# App                   0
# Category              0
# Reviews               0
# Size                  0
# Installs          10357
# Type                  1
# Price                 0
# Content Rating        1
# Genres                0
# Last Updated          0
# Current Ver           8
# Android Ver           3
# dtype: int64

# %% [markdown]
# # Phase 5: Handling Inconsistent Data

# %% [markdown]
# Tasks
#
# Identify and clean:
# * Currency symbols
# * Commas
# * Plus signs
# * Text values inside numerical columns
# * Invalid entries
# * Special characters

# %%
df[['Installs','Price','Size','Reviews']].head(10)
# Out:
#    Installs Price  Size Reviews
# 0       NaN     0   19M     159
# 1       NaN     0   14M     967
# 2       NaN     0  8.7M   87510
# 3       NaN     0   25M  215644
# 4       NaN     0  2.8M     967
# 5       NaN     0  5.6M     167
# 6       NaN     0   19M     178
# 7       NaN     0   29M   36815
# 8       NaN     0   33M   13791
# 9       NaN     0  3.1M     121

# %%
df['Installs'].unique()[:20]
# Out:
# array([nan,  0.])

# %%
df['Size'].unique()[:20]
# Out:
# <StringArray>
# [ '19M',  '14M', '8.7M',  '25M', '2.8M', '5.6M',  '29M',  '33M', '3.1M',
#   '28M',  '12M',  '20M',  '21M',  '37M', '2.7M', '5.5M',  '17M',  '39M',
#   '31M', '4.2M']
# Length: 20, dtype: str

# %%
df['Type'].unique()
# Out:
# <StringArray>
# ['Free', 'Paid', nan, '0']
# Length: 4, dtype: str

# %% [markdown]
# # Phase 6: Outlier Detection & Treatment

# %% [markdown]
# Analyze:
#
# * Rating
# * Reviews
# * Installs
# * Price
#
# Tasks
#
# 1. Visualize outliers using boxplots.
# 2. Detect outliers using the IQR method.
# 3. Detect outliers using Z-score.
# 4. Remove outliers.
# 5. Apply outlier capping.
# 6. Compare both approaches.

# %%
# df = pd.read_csv('googleplaystore.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import zscore

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import zscore

outlier_cols = [
    'Rating',
    'Reviews',
    'Installs',
    'Price'
]

# Boxplots
for col in outlier_cols:

    plt.figure(figsize=(8,4))
    sns.boxplot(x=df[col])
    plt.title(col)
    plt.show()

# IQR Detection
for col in outlier_cols:

    Q1 = df[col].quantile(0.25)

    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR

    upper = Q3 + 1.5 * IQR

    outliers = df[
        (df[col] < lower) |
        (df[col] > upper)
    ]

    print(col, len(outliers))

# Z-score
z_scores = np.abs(
    zscore(df[outlier_cols])
)

for i, col in enumerate(outlier_cols):

    print(
        col,
        (z_scores[:,i] > 3).sum()
    )

# Capping
df_capped = df.copy()

for col in outlier_cols:

    Q1 = df[col].quantile(0.25)

    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR

    upper = Q3 + 1.5 * IQR

    df_capped[col] = np.where(
        df_capped[col] > upper,
        upper,
        df_capped[col]
    )

    df_capped[col] = np.where(
        df_capped[col] < lower,
        lower,
        df_capped[col]
    )

print("Original Shape:", df.shape)

print("Capped Shape:", df_capped.shape)
# Out:
# Rating 496
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[182], line 24
#      21 # IQR Detection
#      22 for col in outlier_cols:
# ---> 24     Q1 = df[col].quantile(0.25)
#      26     Q3 = df[col].quantile(0.75)
#      28     IQR = Q3 - Q1
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:2677, in Series.quantile(self, q, interpolation)
#    2673 # We dispatch to DataFrame so that core.internals only has to worry
#    2674 #  about 2D cases.
#    2675 df = self.to_frame()
# -> 2677 result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#    2678 if result.ndim == 2:
#    2679     result = result.iloc[:, 0]
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:16120, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   16114 axis = self._get_axis_number(axis)
#   16116 if not is_list_like(q):
#   16117     # BlockManager.quantile expects listlike, so we wrap and unwrap here
#   16118     # error: List item 0 has incompatible type "float | ExtensionArray |
#   16119     # ndarray[Any, Any] | Index | Series | Sequence[float]"; expected "float"
# > 16120     res_df = self.quantile(
#   16121         [q],  # type: ignore[list-item]
#   16122         axis=axis,
#   16123         numeric_only=numeric_only,
#   16124         interpolation=interpolation,
#   16125         method=method,
#   16126     )
#   16127     if method == "single":
#   16128         res = res_df.iloc[0]
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:16165, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   16161     raise ValueError(
#   16162         f"Invalid method: {method}. Method must be in {valid_method}."
#   16163     )
#   16164 if method == "single":
# > 16165     res = data._mgr.quantile(qs=q, interpolation=interpolation)
#   16166 elif method == "table":
#   16167     valid_interpolation = {"nearest", "lower", "higher"}
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:1720, in BlockManager.quantile(self, qs, interpolation)
#    1715 assert is_list_like(qs)  # caller is responsible for this
#    1717 new_axes = [self.axes[0].view(), Index(qs, dtype=np.float64)]
#    1719 blocks = [
# -> 1720     blk.quantile(qs=qs, interpolation=interpolation) for blk in self.blocks
#    1721 ]
#    1723 return type(self)(blocks, new_axes)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\blocks.py:1495, in Block.quantile(self, qs, interpolation)
#    1492 assert self.ndim == 2
#    1493 assert is_list_like(qs)  # caller is responsible for this
# -> 1495 result = quantile_compat(self.values, np.asarray(qs._values), interpolation)
#    1496 # ensure_block_shape needed for cases where we start with EA and result
#    1497 #  is ndarray, e.g. IntegerArray, SparseArray
#    1498 result = ensure_block_shape(result, ndim=2)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\array_algos\quantile.py:41, in quantile_compat(values, qs, interpolation)
#      39     return quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      40 else:
# ---> 41     return values._quantile(qs, interpolation)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arrays\_mixins.py:512, in NDArrayBackedExtensionArray._quantile(self, qs, interpolation)
#     509 arr = self._ndarray
#     510 fill_value = self._internal_fill_value
# --> 512 res_values = quantile_with_mask(arr, mask, fill_value, qs, interpolation)
#     513 if res_values.dtype == self._ndarray.dtype:
#     514     return self._from_backing_data(res_values)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\array_algos\quantile.py:84, in quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      82     values = np.atleast_2d(values)
#      83     mask = np.atleast_2d(mask)
# ---> 84     res_values = quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      85     return res_values[0]
#      87 assert values.ndim == 2
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\array_algos\quantile.py:97, in quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      95     result = np.repeat(flat, len(values)).reshape(len(values), len(qs))
#      96 else:
# ---> 97     result = _nanquantile(
#      98         values,
#      99         qs,
#     100         na_value=fill_value,
#     101         mask=mask,
#     102         interpolation=interpolation,
#     103     )
#     105     result = np.asarray(result)
#     106     result = result.T
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\array_algos\quantile.py:218, in _nanquantile(values, qs, na_value, mask, interpolation)
#     216     return result
#     217 else:
# --> 218     return np.quantile(
#     219         values,
#     220         qs,
#     221         axis=1,
#     222         # error: No overload variant of "percentile" matches argument types
#     223         # "ndarray[Any, Any]", "ndarray[Any, dtype[floating[_64Bit]]]",
#     224         # "int", "Dict[str, str]"  [call-overload]
#     225         method=interpolation,  # type: ignore[call-overload]
#     226     )
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:4556, in quantile(a, q, axis, out, overwrite_input, method, keepdims, weights, interpolation)
#    4553     if np.any(weights < 0):
#    4554         raise ValueError("Weights must be non-negative.")
# -> 4556 return _quantile_unchecked(
#    4557     a, q, axis, out, overwrite_input, method, keepdims, weights)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:4569, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims, weights)
#    4560 def _quantile_unchecked(a,
#    4561                         q,
#    4562                         axis=None,
#    (...)   4566                         keepdims=False,
#    4567                         weights=None):
#    4568     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4569     return _ureduce(a,
#    4570                     func=_quantile_ureduce_func,
#    4571                     q=q,
#    4572                     weights=weights,
#    4573                     keepdims=keepdims,
#    4574                     axis=axis,
#    4575                     out=out,
#    4576                     overwrite_input=overwrite_input,
#    4577                     method=method)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:3914, in _ureduce(a, func, keepdims, **kwargs)
#    3911     index_out = (0, ) * nd
#    3912     kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3914 r = func(a, **kwargs)
#    3916 if out is not None:
#    3917     return out
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:4744, in _quantile_ureduce_func(a, q, weights, axis, out, overwrite_input, method)
#    4742     arr = a.copy()
#    4743     wgt = weights
# -> 4744 result = _quantile(arr,
#    4745                    quantiles=q,
#    4746                    axis=axis,
#    4747                    method=method,
#    4748                    out=out,
#    4749                    weights=wgt)
#    4750 return result
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:4876, in _quantile(arr, quantiles, axis, method, out, weights)
#    4874         result_shape = virtual_indexes.shape + (1,) * (arr.ndim - 1)
#    4875         gamma = gamma.reshape(result_shape)
# -> 4876         result = _lerp(previous,
#    4877                     next,
#    4878                     gamma,
#    4879                     out=out)
#    4880 else:
#    4881     # Weighted case
#    4882     # This implements method="inverted_cdf", the only supported weighted
#    4883     # method, which needs to sort anyway.
#    4884     weights = np.asanyarray(weights)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:4671, in _lerp(a, b, t, out)
#    4657 def _lerp(a, b, t, out=None):
#    4658     """
#    4659     Compute the linear interpolation weighted by gamma on each point of
#    4660     two same shape array.
#    (...)   4669         Output array.
#    4670     """
# -> 4671     diff_b_a = subtract(b, a)
#    4672     # asanyarray is a stop-gap until gh-13105
#    4673     lerp_interpolation = asanyarray(add(a, diff_b_a * t, out=out))
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %% [markdown]
# # Phase 7: Feature Transformation

# %% [markdown]
# Tasks
#
# Check skewness of:
#
# * Reviews
# * Installs
# * Price
#
# Apply:
# * Log Transformation
#
# np.log1p()
#
# * Square Root Transformation
#
# np.sqrt()

# %% [markdown]
# # Phase 8: Feature Encoding

# %% [markdown]
# Tasks
#
# Apply Label Encoding on:
#
# * Type
#
# #### Apply One-Hot Encoding on:
#
# * Category
# * Content Rating
# * Genres

# %%
df = pd.read_csv('googleplaystore.csv')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df['Type'] = lb.fit_transform(df['Type'])

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder(sparse_output=False)

# %%
df['Category'] = ohe.fit_transform(df[['Category']])
df['Content Rating'] = ohe.fit_transform(df[['Content Rating']])
df['Genres'] = ohe.fit_transform(df[['Genres']])

# %% [markdown]
# # Phase 9: Feature Scaling

# %% [markdown]
# Tasks
#
# Apply:
# * StandardScaler
# * MinMaxScaler
# ### on:
# * Rating
# * Reviews
# * Installs
# * Price

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("googleplaystore.csv")



df = df.drop_duplicates()


df['Reviews'] = pd.to_numeric(
    df['Reviews'],
    errors='coerce'
)



df['Installs'] = (
    df['Installs']
    .astype(str)
    .str.replace(',', '', regex=False)
    .str.replace('+', '', regex=False)
)

df['Installs'] = pd.to_numeric(
    df['Installs'],
    errors='coerce'
)


df['Price'] = (
    df['Price']
    .astype(str)
    .str.replace('$', '', regex=False)
)

df['Price'] = pd.to_numeric(
    df['Price'],
    errors='coerce'
)



def convert_size(size):

    if pd.isna(size):
        return np.nan

    size = str(size)

    if size == 'Varies with device':
        return np.nan

    elif 'M' in size:
        return float(size.replace('M', '')) * 1000000

    elif 'k' in size:
        return float(size.replace('k', '')) * 1000

    else:
        return np.nan

df['Size'] = df['Size'].apply(convert_size)


df['Rating'] = pd.to_numeric(
    df['Rating'],
    errors='coerce'
)


cat_cols = df.select_dtypes(
    include='object'
).columns

for col in cat_cols:
    df[col] = df[col].str.strip()


num_cols = df.select_dtypes(
    include=['int64','float64']
).columns

for col in num_cols:
    df[col] = df[col].fillna(
        df[col].median()
    )

cat_cols = df.select_dtypes(
    include='object'
).columns

for col in cat_cols:
    df[col] = df[col].fillna(
        df[col].mode()[0]
    )



print(df.dtypes)



print("\nMissing Values:")
print(df.isnull().sum())

print("\nDataset Shape:")
print(df.shape)


df.to_csv(
    "google_playstore_cleaned.csv",
    index=False
)

print("\nDataset Cleaned Successfully!")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6520\3785323312.py:72: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = df.select_dtypes(
# C:\Users\HP\AppData\Local\Temp\ipykernel_6520\3785323312.py:89: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = df.select_dtypes(
# App                   str
# Category              str
# Rating            float64
# Reviews           float64
# Size              float64
# Installs          float64
# Type                  str
# Price             float64
# Content Rating        str
# Genres                str
# Last Updated          str
# Current Ver           str
# Android Ver           str
# dtype: object
#
# Missing Values:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64
#
# Dataset Shape:
# (10358, 13)
#
# Dataset Cleaned Successfully!

# %%
from sklearn.preprocessing import StandardScaler , MinMaxScaler

# %%
sc = StandardScaler()

# %%
df['Rating'] = sc.fit_transform(df[['Rating']])
df['Reviews'] = sc.fit_transform(df[['Reviews']])
df['Installs'] = sc.fit_transform(df[['Installs']])
df['Price'] = sc.fit_transform(df[['Price']])

# %%
mn = MinMaxScaler()

# %%
df['Rating'] = mn.fit_transform(df[['Rating']])
df['Reviews'] = mn.fit_transform(df[['Reviews']])
df['Installs'] = mn.fit_transform(df[['Installs']])
df['Price'] = mn.fit_transform(df[['Price']])
