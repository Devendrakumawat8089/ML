# %%
print("MinMaxScaling Pratice , Dataset =  Clicks.csv ")
# Out:
# MinMaxScaling Pratice , Dataset =  Clicks.csv

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("click.csv")

# %%
df.head()
# Out:
#    Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 0                     62.26  32.0     69481.85                172.83
# 1                     41.73  31.0     61840.26                207.17
# 2                     44.40  30.0     57877.15                172.83
# 3                     59.88  28.0     56180.93                207.17
# 4                     49.21  30.0     54324.73                201.58
#
#                          Ad Topic Line             City  Gender  \
# 0      Decentralized real-time circuit         Lisafort    Male
# 1       Optional full-range projection  West Angelabury    Male
# 2  Total 5thgeneration standardization        Reyesfurt  Female
# 3          Balanced empowering success      New Michael  Female
# 4  Total 5thgeneration standardization     West Richard  Female
#
#                         Country            Timestamp  Clicked on Ad
# 0  Svalbard & Jan Mayen Islands  2016-06-09 21:43:05              0
# 1                     Singapore  2016-01-16 17:56:05              0
# 2                    Guadeloupe  2016-06-29 10:50:45              0
# 3                        Zambia  2016-06-21 14:32:32              0
# 4                         Qatar  2016-07-21 10:54:35              1

# %%
df.drop(columns=['Ad Topic Line'], inplace=True)
df.drop(columns=['City'] , inplace=True)
df.drop(columns=['Country'], inplace=True)
df.drop(columns=['Timestamp'],inplace=True)

# %%
df['Gender'] = df['Gender'].map({"Male":0 , "Female":1})

# %%
df
# Out:
#       Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 0                        62.26  32.0     69481.85                172.83
# 1                        41.73  31.0     61840.26                207.17
# 2                        44.40  30.0     57877.15                172.83
# 3                        59.88  28.0     56180.93                207.17
# 4                        49.21  30.0     54324.73                201.58
# ...                        ...   ...          ...                   ...
# 9995                     41.73  31.0     61840.26                207.17
# 9996                     41.73  28.0     51501.38                120.49
# 9997                     55.60  39.0     38067.08                124.44
# 9998                     46.61  50.0     43974.49                123.13
# 9999                     46.61  43.0     60575.99                198.45
#
#       Gender  Clicked on Ad
# 0          0              0
# 1          0              0
# 2          1              0
# 3          1              0
# 4          1              1
# ...      ...            ...
# 9995       0              1
# 9996       0              0
# 9997       1              0
# 9998       1              1
# 9999       0              1
#
# [10000 rows x 6 columns]

# %%
x = df.drop(columns=['Area Income'])
y = df['Area Income']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2 , random_state=42)

# %%
np.round(x_train.describe(),2)
# Out:
#        Daily Time Spent on Site      Age  Daily Internet Usage   Gender  \
# count                   8000.00  8000.00               8000.00  8000.00
# mean                      61.75    36.00                177.54     0.54
# std                       15.74     8.56                 40.80     0.50
# min                       32.60    19.00                105.22     0.00
# 25%                       48.86    29.00                140.15     0.00
# 50%                       59.59    35.00                178.92     1.00
# 75%                       76.81    42.00                212.38     1.00
# max                       90.97    60.00                269.96     1.00
#
#        Clicked on Ad
# count        8000.00
# mean            0.49
# std             0.50
# min             0.00
# 25%             0.00
# 50%             0.00
# 75%             1.00
# max             1.00

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mn = MinMaxScaler()

# %%
x_train_mn = mn.fit_transform(x_train)

# %%
x_train_new = pd.DataFrame(x_train_mn , columns= x_train.columns)

# %%
np.round(x_train_new.describe(),2)
# Out:
#        Daily Time Spent on Site      Age  Daily Internet Usage   Gender  \
# count                   8000.00  8000.00               8000.00  8000.00
# mean                       0.50     0.41                  0.44     0.54
# std                        0.27     0.21                  0.25     0.50
# min                        0.00     0.00                  0.00     0.00
# 25%                        0.28     0.24                  0.21     0.00
# 50%                        0.46     0.39                  0.45     1.00
# 75%                        0.76     0.56                  0.65     1.00
# max                        1.00     1.00                  1.00     1.00
#
#        Clicked on Ad
# count        8000.00
# mean            0.49
# std             0.50
# min             0.00
# 25%             0.00
# 50%             0.00
# 75%             1.00
# max             1.00
