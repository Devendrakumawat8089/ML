# %%
print("Matplotlib")
# Out:
# Matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Line chart --> plot

# %%
x = [1,2,3,4,5,6,7]
y= [10,20,30,40,50,60,70]

plt.plot(x,y, color='red' , marker = 'o' )
plt.show()

# %%
plt.bar(x,y)
plt.show()
