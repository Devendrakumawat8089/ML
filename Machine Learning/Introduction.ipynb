# %%
print("Introduction Of The Machine Learning")

# %% [markdown]
# #  What is Machine Learning ?.

# %% [markdown]
# Machine learning is a subset of Artificial Intelligence (AI) where computers learn from data and identify patterns without being explicitly programmed

# %% [markdown]
# # 3 types Of Machine Learning

# %% [markdown]
# 1. Supervised Learning
#     * regression ( Continuous Points Predicts)
#     * Classification (Classes Predicts)
# 2. UnSupervised Learning
# 3. Semi-Supervised
# 4. Reinforcement Learning

# %%
# 1. Supervised Learning :in Supervised Learning We Basically Train the Model On The Labeled Data (labeled Means The Dataset Is Having Target Column)

# %%
# 1. Regression Algorithm
# 2. Logistic 
# 3. Decission Tree --> Decission Tree Classifier | Decission Tree Regressor
# 4. SVM (Support Vector Machine) --> SVC(Support Vercotr Classifier) | SVR (Support Vector Regressor)
# 5. Ensence Learning --. RandomForest --> RFC | RFR
# 6. KNN 
# 7. Naive Bayes Algorithm

# %%
# 2. UnSupervised Learning : --> Unsupervised Learning IS A Learning Algo. In Which We Basically Train the Model On The Unlabeled Data(No One Target Column)

# %%
# into This Type OF machine Learning We Basically Cluster The Or Group The Data On Some Simillar Points

# %%
# Customer Signematation (30k + 10k- | 30k + 10k+ | 30k- 10k-)
# Types 
# 1. KMeans Clustering 
# 2. DBSEAN
# 3. Herirarchical Clustering
# 4. PCA 
# 5. Apriari Algorithm
