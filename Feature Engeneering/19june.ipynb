# %%
print("imbalanced dataset")
# Out:
# imbalanced dataset

# %%
import numpy as np
import pandas as pd

# %%
# # UnderSmapling --> It Is A Technique In Which The Majority Class Points Are reduced to the minority class 
# (DisAdvanced)
# * Data Loss
# * Model Will not able learn

#  Oversampling --> Into This Sampling Techniquye The Minority Class Members Are Increased To The Number OF Majority Class 
# * (Majority) A --> 90 --> 90
# * (minority) b --> 10 --> 90

# SMOTE (Synthetic Minority Oversampling Technique)  --> In This Technique we basically Create synthetic point btw the minority class point to oversimple the data

# %%
# undersampling , oversampling , smote

# %%
# !pip install imbalanced-learn

# %%
from sklearn.datasets import make_classification
from collections import Counter

X, y = make_classification(
    n_samples=1000,
    n_features=10,
    n_classes=2,
    weights=[0.9, 0.1],  # 90% class 0, 10% class 1
    random_state=42
)

print(Counter(y))
# Out:
# Counter({np.int64(0): 897, np.int64(1): 103})

# %%
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter

rus = RandomUnderSampler(random_state=42)

X_under, y_under = rus.fit_resample(X, y)

print(Counter(y_under))
# Out:
# Counter({np.int64(0): 103, np.int64(1): 103})

# %%
# OverSampling
from imblearn.over_sampling import RandomOverSampler
from collections import Counter

ros = RandomOverSampler(random_state=42)

X_over, y_over = ros.fit_resample(X, y)

print(Counter(y_over))
# Out:
# Counter({np.int64(0): 897, np.int64(1): 897})

# %%
# SMOTE
from imblearn.over_sampling import SMOTE
from collections import Counter

smote = SMOTE(random_state=42)

X_smote, y_smote = smote.fit_resample(X, y)

print(Counter(y_smote))
# Out:
# Counter({np.int64(0): 897, np.int64(1): 897})

# %%
# Before Start Machine Learning 

#  22 variance trad of 
# underfitting 
# overfitting

# %%
import numpy as np
