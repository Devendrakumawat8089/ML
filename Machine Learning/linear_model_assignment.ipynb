# %%
print("Linear Regression Model Assignment")
# Out:
# Linear Regression Model Assignment

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('employee_salary_dataset(1).csv')
df.sample(1)
# Out:
#     EmployeeID         Name Department  Experience_Years Education_Level  Age  \
# 14          15  Employee_15  Marketing                10             PhD   49
#
#     Gender    City  Monthly_Salary
# 14  Female  Mumbai           99290

# %%
df.shape
# Out:
# (50, 9)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EmployeeID        50 non-null     int64
#  1   Name              50 non-null     str
#  2   Department        50 non-null     str
#  3   Experience_Years  50 non-null     int64
#  4   Education_Level   50 non-null     str
#  5   Age               50 non-null     int64
#  6   Gender            50 non-null     str
#  7   City              50 non-null     str
#  8   Monthly_Salary    50 non-null     int64
# dtypes: int64(4), str(5)
# memory usage: 3.6 KB

# %%
df.isna().sum()
# Out:
# EmployeeID          0
# Name                0
# Department          0
# Experience_Years    0
# Education_Level     0
# Age                 0
# Gender              0
# City                0
# Monthly_Salary      0
# dtype: int64

# %%
num_col = df.select_dtypes(include=['int64','float64']).columns
num_col
# Out:
# Index(['EmployeeID', 'Experience_Years', 'Age', 'Monthly_Salary'], dtype='str')

# %%
cat_col =df.select_dtypes(include=['str']).columns
cat_col
# Out:
# Index(['Name', 'Department', 'Education_Level', 'Gender', 'City'], dtype='str')

# %%
for col in df.columns:
    plt.Figure(figsize=(5,5))
    plt.title(col)
    sns.boxplot(df[col])
    plt.show()

# %%
# sns.scatterplot(x=df['EmployeeID'],y=df['Monthly_Salary'])

# %%
# sns.countplot(df)

# %%
df=df.drop_duplicates()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
# ['Name', 'Department', 'Education_Level', 'Gender', 'City'], dtype='str'
df['Name'] = lb.fit_transform(df['Name'])
df['Department'] = lb.fit_transform(df['Department'])
df['Education_Level'] = lb.fit_transform(df['Education_Level'])
df['Gender'] = lb.fit_transform(df['Gender'])
df['City'] = lb.fit_transform(df['City'])

# %%
df
# Out:
#     EmployeeID  Name  Department  Experience_Years  Education_Level  Age  \
# 0            1     0           3                15                2   53
# 1            2    11           4                 7                0   25
# 2            3    22           2                12                1   51
# 3            4    33           4                 8                3   44
# 4            5    44           4                15                2   36
# 5            6    46           0                 3                1   50
# 6            7    47           2                14                3   57
# 7            8    48           2                17                3   34
# 8            9    49           2                 4                0   53
# 9           10     1           4                18                1   28
# 10          11     2           3                 8                3   43
# 11          12     3           2                 4                2   49
# ...
