# %%
print("Day 8 ")
# Out:
# Day 8

# %%
print("hari Om Dadu Ra, Ssathiya Ram Shri Ram ,Jai Jai Jai ram , ohh shri jau ram jai jai ram ")
# Out:
# hari Om Dadu Ra, Ssathiya Ram Shri Ram ,Jai Jai Jai ram , ohh shri jau ram jai jai ram
