# %%
# !pip install pypdf
# Out:
# Collecting pypdf
#   Downloading pypdf-6.15.0-py3-none-any.whl.metadata (7.5 kB)
# Downloading pypdf-6.15.0-py3-none-any.whl (378 kB)
# Installing collected packages: pypdf
# Successfully installed pypdf-6.15.0
# [notice] A new release of pip is available: 26.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pypdf import PdfReader

reader = PdfReader("Machine Learning Important Questions .pdf")

for page_number, page in enumerate(reader.pages, start=1):
    text = page.extract_text()

    print(f"\n--- Page {page_number} ---")
    print(text)
# Out:
# --- Page 1 ---
# Q1. what is the main goal of LinearRegression Model
# The main goal of the Linear Regression model is:
# To predict a continuous numerical value by finding the relationship between input variables
# and output variables.
# Suppose you have data:
# Hours Studied Marks
# 1 40
# 2 50
# 3 60
# 4 70
# Linear Regression learns the pattern:
# Marks=10×Hours+30Marks=10×Hours+30
# Now if a student studies for 5 hours:
# Marks=10(5)+30=80Marks=10(5)+30=80
# So the model predicts 80 marks.
# Main Goals of Linear Regression
# 1. Prediction
# Used to predict numerical values like:
# House prices
# Salary prediction
# Temperature forecasting
# Sales prediction
# 2. Find Relationship Between Variables
# It helps understand:
# How one variable affects another
# Positive or negative impact
# Example:
# More advertising → more sales
#
# --- Page 2 ---
# 3. Trend Analysis
# It identifies trends in data using a straight-line relationship.
# Formula of Linear Regression
# y=mx+by=mx+b
# Where:
# y = predicted output
# x = input feature
# m = slope (change rate)
# b = intercept
# In Machine Learning
# Linear Regression is a:
# Supervised Learning Algorithm
# Used for Regression Problems
# Works with continuous output values
# Real-Life Applications
# Stock price prediction
# Weather forecasting
# Business sales prediction
# Fraud amount estimation
# Student performance prediction
# Q2. What is the difference Between Simple LinearRegression And Multiple LinearRegression.
# Difference Between Simple Linear Regression and Multiple Linear
# Regression
#
# --- Page 3 ---
# Basis Simple Linear RegressionMultiple Linear Regression
# Number of Input Variables Only 1 independent variable2 or more independent
# variables
# Purpose Predict output using one factorPredict output using multiple
# factors
# Formula y=mx+by=mx+b y=b0+b1x1+b2x2+...y=b0 +b1 x1
# +b2 x2 +...
# Complexity Simple and easy More complex
# Example Marks based on study hoursMarks based on study hours,
# sleep, attendance
# Graph Straight line in 2D Plane/hyperplane in multi-
# dimensions
# 1. Simple Linear Regression
# In Simple Linear Regression:
# There is one input feature (X)
# One output variable (Y)
# Example
# Predict salary using:
# Years of experience only
# Salary=m(Experience)+bSalary=m(Experience)+b
# Dataset Example
# Experience Salary
# 1 year 20k
# 2 years 30k
# 3 years 40k
# Here:
# Input = Experience
# Output = Salary
# 2. Multiple Linear Regression
#
# --- Page 4 ---
# In Multiple Linear Regression:
# There are multiple input features
# One output variable
# Example
# Predict house price using:
# Area
# Number of rooms
# Location
# Age of house
# Formula:
# y=b0+b1x1+b2x2+b3x3y=b0+b1x1+b2x2+b3x3
# Dataset Example
# Area Rooms Age Price
# 1000 2 5 20L
# 1500 3 2 35L
# Here:
# Multiple inputs affect the output
# Key Difference in One Line
# Simple Linear Regression → One input variable
# Multiple Linear Regression → Multiple input variables
# Real-Life Analogy
# Simple Linear Regression
# Marks depend only on:
# Study hours
# Multiple Linear Regression
# Marks depend on:
# Study hours
#
# --- Page 5 ---
# Sleep
# Attendance
# Practice
# So Multiple Linear Regression gives more realistic predictions because many factors are considered
# together.
# Q3. What is the Best Fit Line In LinearRegression?
# Best Fit Line in Linear Regression
# The Best Fit Line is the straight line that passes through the data points in such a way that it gives
# the minimum prediction error.
# It is also called:
# Regression Line
# Line of Best Fit
# Simple Definition
# The best fit line is the line that best represents the relationship between input data (X) and output
# data (Y).
# Example
# Suppose we have data:
# Hours Studied Marks
# 1 40
# 2 50
# 3 60
# 4 70
# Linear Regression tries to draw a line that is closest to all points.
# The equation may become:
# y=10x+30y=10x+30
# Where:
# xx = study hours
#
# --- Page 6 ---
# yy = predicted marks
# 10 = slope
# 30 = intercept
# Why is it called “Best” Fit?
# Because this line minimizes the total error between:
# Actual values
# Predicted values
# The error is calculated using:
# Residuals
# Mean Squared Error (MSE)
# Residual (Error)
# Residual=Actual Value−Predicted ValueResidual=Actual Value−Predicted Value
# The best fit line tries to make all residuals as small as possible.
# Goal of Best Fit Line
# Predict future values
# Show relationship between variables
# Minimize prediction errors
# Real-Life Example
# If:
# More study hours generally increase marks
# Then the best fit line shows this trend clearly and helps predict marks for new students.
# Important Point
# The line usually does not pass through every point exactly because real-world data contains:
# Noise
# Random variations
# Outliers
# So Linear Regression finds the line that is closest to all points overall.
# Q4. What Do Slop And intershep represent in LinearRegression.?
#
# --- Page 7 ---
# What do Slope and Intercept represent in Linear Regression?
# Linear Regression equation:
# y=mx+by=mx+b
# mm
# bb
# Slope and intercept sliders update the line on the graph.
# -10-8-6-4-2246810-10-5510y-interceptx-intercept
# Where:
# yy = predicted output
# xx = input variable
# mm = slope
# bb = intercept
# 1. Slope (m)
# Meaning
# Slope represents:
# How much the output changes when the input changes by 1 unit.
# It shows:
# Direction of relationship
# Rate of change
# Example
# Equation:
# y=10x+30y=10x+30
# Here:
# Slope m=10m=10
# Meaning:
# If study hours increase by 1 hour,
# Marks increase by 10 marks.
#
# --- Page 8 ---
# Types of Slope
# Positive Slope
# m>0m>0
# As xx increases, yy increases.
# Example:
# More study → more marks
# Negative Slope
# m<0m<0
# As xx increases, yy decreases.
# Example:
# More speed → less travel time
# 2. Intercept (b)
# Meaning
# Intercept represents:
# The value of yy when x=0x=0.
# It is the point where the line crosses the Y-axis.
# Example
# Equation:
# y=10x+30y=10x+30
# Here:
# Intercept b=30b=30
# Meaning:
# If study hours are 0,
# Predicted marks are 30.
# Real-Life Analogy
# Suppose:
#
# --- Page 9 ---
# Taxi fare starts at ₹50
# Then ₹10 per kilometer
# Equation:
# Fare=10x+50Fare=10x+50
# Where:
# 10 = slope (charge per km)
# 50 = intercept (starting charge)
# Summary Table
# Term Symbol Meaning
# Slope mm Change in output for 1-
# unit input change
# Intercept bb Output value when input
# is 0
# Q5. What Should You Use LinearRegression  And When Should You Not Use
# LinearRegression. ?
# When Should You Use Linear Regression and When Should
# You NOT Use It?
# ✅  When You Should Use Linear Regression
# Linear Regression should be used when:
# 1. Output is Continuous (Numerical)
# Use it when you want to predict values like:
# House price
# Salary
# Temperature
# Sales amount
# Examples
# Predicting student marks
#
# --- Page 10 ---
# Predicting monthly profit
# Predicting fuel consumption
# 2. Relationship Between Variables is Linear
# Use Linear Regression when data follows an approximately straight-line relationship.
# Example:
# More study hours → higher marks
# 3. You Want Simple and Interpretable Models
# Linear Regression is easy to:
# Understand
# Train
# Explain
# Good for beginners and business analysis.
# 4. Small to Medium Sized Datasets
# It works well on:
# Clean datasets
# Structured/tabular data
# 5. Need Fast Training
# Linear Regression is computationally fast compared to complex ML models.
# ✅  Real-Life Use Cases
# Problem Use Linear Regression?
# House price prediction Yes
# Sales forecasting Yes
# Salary prediction Yes
# Temperature prediction Yes
#
# --- Page 11 ---
# ❌  When You Should NOT Use Linear Regression
# 1. When Relationship is Non-Linear
# If data forms:
# Curve
# Complex pattern
# Exponential relationship
# Then Linear Regression performs poorly.
# Example
# Population growth over time.
# 2. For Classification Problems
# Linear Regression is NOT suitable when output is categories like:
# Yes/No
# Spam/Not Spam
# Fraud/Not Fraud
# Use:
# Logistic Regression
# Decision Trees
# Classification algorithms
# instead.
# 3. When Data Has Many Outliers
# Outliers strongly affect the best fit line.
# Example:
# One extremely high salary value can disturb predictions.
# 4. When Features Are Highly Correlated
# If input variables depend heavily on each other:
# Multicollinearity problem occurs
# Model becomes unstable
# 5. When Data is Very Complex
#
# --- Page 12 ---
# For:
# Images
# Audio
# NLP tasks
# Deep patterns
# Use:
# Neural Networks
# Deep Learning
# Advanced ML algorithms
# Summary Table
# Situation Use Linear Regression?
# Predict continuous values ✅  Yes
# Straight-line relationship ✅  Yes
# Simple model needed ✅  Yes
# Classification problem ❌  No
# Non-linear data ❌  No
# Complex image/text data ❌  No
# One-Line Conclusion
# Use Linear Regression for simple numerical prediction problems with linear relationships, but avoid it
# for classification, highly complex, or non-linear data problems.
# Q6.  What Is Difference Between Overfitting And UnderFitting . ?
# Difference Between Overfitting and Underfitting
# In Machine Learning, both Overfitting and Underfitting are problems related to model performance.
# 1. Underfitting
# Meaning
# Underfitting happens when:
# The model is too simple to learn the pattern in the data.
#
# --- Page 13 ---
# The model cannot capture important relationships.
# Characteristics
# Poor performance on training data
# Poor performance on testing data
# High bias
# Low accuracy
# Example
# Suppose data is curved, but the model tries to fit only a straight line.
# Then predictions become inaccurate.
# Real-Life Analogy
# A student studies only 1 page before exam:
# Cannot understand concepts properly
# Performs badly everywhere
# Causes of Underfitting
# Model too simple
# Too little training
# Important features missing
# 2. Overfitting
# Meaning
# Overfitting happens when:
# The model learns the training data too perfectly, including noise and unnecessary details.
# It memorizes instead of learning general patterns.
# Characteristics
# Very high training accuracy
# Poor testing accuracy
# High variance
# Poor generalization
# Example
# The model tries to pass through every data point exactly.
#
# --- Page 14 ---
# It becomes too complex.
# Real-Life Analogy
# A student memorizes answers exactly:
# Performs well on same questions
# Fails on new questions
# Causes of Overfitting
# Too complex model
# Too much training
# Small dataset
# Noise in data
# Main Difference
# Feature Underfitting Overfitting
# Model Complexity Too simple Too complex
# Training Accuracy Low Very high
# Testing Accuracy Low Low
# Learns Pattern Properly? No Learns too much
# Bias High Low
# Variance Low High
# Visualization Idea
# Underfitting
# Straight line on curved data
# Good Fit
# Captures main pattern correctly
# Overfitting
# Zig-zag line touching every point
# How to Prevent Them
# Prevent Underfitting
#
# --- Page 15 ---
# Increase model complexity
# Add more features
# Train longer
# Prevent Overfitting
# Use more data
# Feature selection
# Cross-validation
# Regularization
# Simpler model
# One-Line Conclusion
# Underfitting means the model learns too little, while Overfitting means the model learns too much
# from the training data.
# Q7. What Do You Mean By Regulrize technique . ?
# What Do You Mean by Regularization Technique?
# Regularization is a technique used in Machine Learning to:
# Reduce Overfitting and improve model generalization.
# It helps the model learn important patterns without memorizing the training data.
# Simple Meaning
# Sometimes a model becomes:
# Too complex
# Too sensitive to training data
# Regularization adds a penalty to the model so it stays simpler and more stable.
# Main Goal of Regularization
# ✅  Prevent Overfitting
# ✅  Improve prediction on new data
# ✅  Reduce model complexity
# How Regularization Works
# It adds a penalty term to the loss function.
#
# --- Page 16 ---
# Basic Linear Regression cost function:
# Cost=ErrorCost=Error
# With Regularization:
# Cost=Error+PenaltyCost=Error+Penalty
# The penalty discourages very large weights.
# Types of Regularization
# 1. L1 Regularization (Lasso Regression)
# Penalty uses absolute values of coefficients.
# ∑ ∣ w ∣ ∑ ∣w∣
# Features
# Can make some coefficients exactly 0
# Performs feature selection
# Produces sparse models
# 2. L2 Regularization (Ridge Regression)
# Penalty uses squared values of coefficients.
# ∑w2∑w2
# Features
# Reduces coefficient size
# Does not make them exactly zero
# Most commonly used
# 3. Elastic Net
# Combination of:
# L1 + L2 Regularization
# Used when:
# Dataset has many features
# Features are correlated
# Why Regularization is Important
#
# --- Page 17 ---
# Without regularization:
# Model may memorize noise
# Poor testing accuracy
# With regularization:
# Model becomes balanced
# Better generalization
# Real-Life Analogy
# Suppose a student:
# Memorizes every question answer exactly → Overfitting
# Regularization is like:
# Teaching the student to understand concepts instead of memorizing everything.
# Example
# Imagine predicting house price using many unnecessary features.
# Without regularization:
# Model may give huge importance to irrelevant features.
# With regularization:
# Important features get priority
# Unnecessary features get reduced impact
# Summary Table
# Technique Penalty Type Special Feature
# L1 (Lasso) Absolute values Feature selection
# L2 (Ridge) Squared values Reduces large weights
# Elastic Net Combination Handles correlated
# features
# One-Line Conclusion
# Regularization is a technique used to reduce overfitting by adding a penalty to the model’s complexity
# so that it performs better on new unseen data.
#
# --- Page 18 ---
# Q8. What Is Difference between Rige , Lasso , Elasticnt. ?
# Difference Between Ridge Regression, Lasso Regression, and
# Elastic Net
# All three are Regularization techniques used to reduce:
# Overfitting
# Model complexity
# They are mainly used with Linear Regression models.
# 1. Ridge Regression (L2 Regularization)
# Meaning
# Ridge adds penalty using:
# Square of coefficients
# Formula:
# Loss+λ∑w2Loss+λ∑w2
# Features
# ✅  Reduces large coefficient values
# ✅  Keeps all features
# ✅  Prevents overfitting
# Important Point
# Coefficients become small
# But never exactly 0
# Best Use Case
# Use Ridge when:
# Most features are useful
# Multicollinearity exists
# 2. Lasso Regression (L1 Regularization)
# Meaning
#
# --- Page 19 ---
# Lasso adds penalty using:
# Absolute value of coefficients
# Formula:
# Loss+λ∑ ∣ w ∣ Loss+λ∑ ∣w∣
# Features
# ✅  Can make coefficients exactly 0
# ✅  Performs feature selection
# ✅  Removes unimportant features
# Best Use Case
# Use Lasso when:
# Dataset has many unnecessary features
# Feature selection is needed
# 3. Elastic Net
# Meaning
# Elastic Net combines:
# Ridge + Lasso
# Formula:
# Loss+λ1∑ ∣ w ∣ +λ2∑w2Loss+λ1∑ ∣w∣ +λ2∑w2
# Features
# ✅  Combines benefits of both
# ✅  Handles correlated features well
# ✅  Performs feature selection + coefficient shrinking
# Best Use Case
# Use Elastic Net when:
# Many features exist
# Features are correlated
# Need balanced regularization
# Main Differences
#
# --- Page 20 ---
# Feature Ridge Lasso Elastic Net
# Regularization Type L2 L1 L1 + L2
# Penalty Squared weights Absolute weights Combination
# Feature Selection ❌  No ✅  Yes ✅  Yes
# Coefficients
# Become Zero
# ❌  No ✅  Yes ✅  Sometimes
# Handles
# Multicollinearity
# ✅  Good Moderate ✅  Best
# Model Complexity
# Reduction
# Medium High Balanced
# Simple Analogy
# Suppose 10 students work on a project.
# Ridge
# Keeps all students
# Reduces contribution of weak students
# Lasso
# Removes weak students completely
# Elastic Net
# Removes some weak students
# Reduces contribution of others
# One-Line Conclusion
# Ridge shrinks coefficients, Lasso removes unnecessary features, and Elastic Net combines both
# techniques for balanced regularization.

# %%
# !pip install pdfplumber
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.10-py3-none-any.whl.metadata (43 kB)
# Collecting pdfminer.six==20260107 (from pdfplumber)
#   Downloading pdfminer_six-20260107-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: Pillow>=12.2.0 in c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pdfplumber) (12.2.0)
# Collecting pypdfium2>=5.9.0 (from pdfplumber)
#   Downloading pypdfium2-5.12.1-py3-none-win_amd64.whl.metadata (70 kB)
# Collecting charset-normalizer>=2.0.0 (from pdfminer.six==20260107->pdfplumber)
#   Using cached charset_normalizer-3.4.9-cp313-cp313-win_amd64.whl.metadata (42 kB)
# Collecting cryptography>=36.0.0 (from pdfminer.six==20260107->pdfplumber)
#   Downloading cryptography-50.0.0-cp311-abi3-win_amd64.whl.metadata (4.3 kB)
# Collecting cffi>=2.0.0 (from cryptography>=36.0.0->pdfminer.six==20260107->pdfplumber)
#   Downloading cffi-2.1.1-cp313-cp313-win_amd64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six==20260107->pdfplumber)
#   Using cached pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Downloading pdfplumber-0.11.10-py3-none-any.whl (60 kB)
# Downloading pdfminer_six-20260107-py3-none-any.whl (6.6 MB)
#    ---------------------------------------- 0.0/6.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.6 MB 1.7 MB/s eta 0:00:04
#    ------ --------------------------------- 1.0/6.6 MB 2.0 MB/s eta 0:00:03
#    ------- -------------------------------- 1.3/6.6 MB 1.8 MB/s eta 0:00:03
#    ----------- ---------------------------- 1.8/6.6 MB 1.7 MB/s eta 0:00:03
#    ------------ --------------------------- 2.1/6.6 MB 1.7 MB/s eta 0:00:03
#    -------------- ------------------------- 2.4/6.6 MB 1.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 2.9/6.6 MB 1.7 MB/s eta 0:00:03
#    ------------------- -------------------- 3.1/6.6 MB 1.7 MB/s eta 0:00:03
#    ----------------------- ---------------- 3.9/6.6 MB 1.7 MB/s eta 0:00:02
#    --------------------------- ------------ 4.5/6.6 MB 1.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 4.7/6.6 MB 1.8 MB/s eta 0:00:02
#    ------------------------------- -------- 5.2/6.6 MB 1.8 MB/s eta 0:00:01
#    --------------------------------- ------ 5.5/6.6 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 6.0/6.6 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 6.3/6.6 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 6.6/6.6 MB 1.7 MB/s  0:00:03
# Using cached charset_normalizer-3.4.9-cp313-cp313-win_amd64.whl (161 kB)
# Downloading cryptography-50.0.0-cp311-abi3-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.8 MB 2.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.0/3.8 MB 2.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.6/3.8 MB 2.0 MB/s eta 0:00:02
#    ------------------- -------------------- 1.8/3.8 MB 2.0 MB/s eta 0:00:02
#    ------------------------ --------------- 2.4/3.8 MB 1.8 MB/s eta 0:00:01
#    ------------------------------ --------- 2.9/3.8 MB 1.9 MB/s eta 0:00:01
#    -------------------------------- ------- 3.1/3.8 MB 1.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.4/3.8 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 1.7 MB/s  0:00:02
# Downloading cffi-2.1.1-cp313-cp313-win_amd64.whl (185 kB)
# Downloading pypdfium2-5.12.1-py3-none-win_amd64.whl (3.9 MB)
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.9 MB ? eta -:--:--
#    -------- ------------------------------- 0.8/3.9 MB 1.4 MB/s eta 0:00:03
#    ------------- -------------------------- 1.3/3.9 MB 1.7 MB/s eta 0:00:02
#    ------------- -------------------------- 1.3/3.9 MB 1.7 MB/s eta 0:00:02
#    ------------------- -------------------- 1.8/3.9 MB 1.6 MB/s eta 0:00:02
#    ------------------------ --------------- 2.4/3.9 MB 1.7 MB/s eta 0:00:01
#    --------------------------- ------------ 2.6/3.9 MB 1.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.9/3.9 MB 1.7 MB/s eta 0:00:01
#    -------------------------------- ------- 3.1/3.9 MB 1.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.4/3.9 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 3.9/3.9 MB 1.5 MB/s  0:00:02
# Using cached pycparser-3.0-py3-none-any.whl (48 kB)
# Installing collected packages: pypdfium2, pycparser, charset-normalizer, cffi, cryptography, pdfminer.six, pdfplumber
#
#    ---------------------------------------- 0/7 [pypdfium2]
#    ---------------------------------------- 0/7 [pypdfium2]
#    ---------------------------------------- 0/7 [pypdfium2]
#    ---------------------------------------- 0/7 [pypdfium2]
#    ---------------------------------------- 0/7 [pypdfium2]
#    ---------------------------------------- 0/7 [pypdfium2]
#    ---------------------------------------- 0/7 [pypdfium2]
#    ---------------------------------------- 0/7 [pypdfium2]
#    ---------------------------------------- 0/7 [pypdfium2]
#    ---------------------------------------- 0/7 [pypdfium2]
#    ---------------------------------------- 0/7 [pypdfium2]
#    ---------------------------------------- 0/7 [pypdfium2]
#    ---------------------------------------- 0/7 [pypdfium2]
#    ---------------------------------------- 0/7 [pypdfium2]
#    ---------------------------------------- 0/7 [pypdfium2]
#    ----- ---------------------------------- 1/7 [pycparser]
#    ----- ---------------------------------- 1/7 [pycparser]
#    ----- ---------------------------------- 1/7 [pycparser]
#    ----------- ---------------------------- 2/7 [charset-normalizer]
#    ----------- ---------------------------- 2/7 [charset-normalizer]
#    ----------- ---------------------------- 2/7 [charset-normalizer]
#    ----------- ---------------------------- 2/7 [charset-normalizer]
#    ----------- ---------------------------- 2/7 [charset-normalizer]
#    ----------------- ---------------------- 3/7 [cffi]
#    ----------------- ---------------------- 3/7 [cffi]
#    ----------------- ---------------------- 3/7 [cffi]
#    ----------------- ---------------------- 3/7 [cffi]
#    ----------------- ---------------------- 3/7 [cffi]
#    ----------------- ---------------------- 3/7 [cffi]
#    ----------------- ---------------------- 3/7 [cffi]
#    ----------------- ---------------------- 3/7 [cffi]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------------- ----------- 5/7 [pdfminer.six]
#    ---------------------------- ----------- 5/7 [pdfminer.six]
#    ---------------------------- ----------- 5/7 [pdfminer.six]
#    ---------------------------- ----------- 5/7 [pdfminer.six]
#    ---------------------------- ----------- 5/7 [pdfminer.six]
#    ---------------------------- ----------- 5/7 [pdfminer.six]
#    ---------------------------- ----------- 5/7 [pdfminer.six]
#    ---------------------------- ----------- 5/7 [pdfminer.six]
#    ---------------------------- ----------- 5/7 [pdfminer.six]
#    ---------------------------- ----------- 5/7 [pdfminer.six]
#    ---------------------------- ----------- 5/7 [pdfminer.six]
#    ---------------------------- ----------- 5/7 [pdfminer.six]
#    ---------------------------- ----------- 5/7 [pdfminer.six]
#    ---------------------------- ----------- 5/7 [pdfminer.six]
#    ---------------------------- ----------- 5/7 [pdfminer.six]
#    ---------------------------- ----------- 5/7 [pdfminer.six]
#    ---------------------------- ----------- 5/7 [pdfminer.six]
#    ---------------------------------- ----- 6/7 [pdfplumber]
#    ---------------------------------- ----- 6/7 [pdfplumber]
#    ---------------------------------- ----- 6/7 [pdfplumber]
#    ---------------------------------- ----- 6/7 [pdfplumber]
#    ---------------------------------- ----- 6/7 [pdfplumber]
#    ---------------------------------- ----- 6/7 [pdfplumber]
#    ---------------------------------- ----- 6/7 [pdfplumber]
#    ---------------------------------- ----- 6/7 [pdfplumber]
#    ---------------------------------- ----- 6/7 [pdfplumber]
#    ---------------------------------- ----- 6/7 [pdfplumber]
#    ---------------------------------- ----- 6/7 [pdfplumber]
#    ---------------------------------- ----- 6/7 [pdfplumber]
#    ---------------------------------------- 7/7 [pdfplumber]
#
# Successfully installed cffi-2.1.1 charset-normalizer-3.4.9 cryptography-50.0.0 pdfminer.six-20260107 pdfplumber-0.11.10 pycparser-3.0 pypdfium2-5.12.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pdfplumber

with pdfplumber.open("Machine Learning Important Questions .pdf") as pdf:
    for page in pdf.pages:
        text = page.extract_text()
        print(text)
# Out:
# Q1. what is the main goal of LinearRegression Model
# The main goal of the Linear Regression model is:
# To predict a continuous numerical value by finding the relationship between input variables
# and output variables.
# Suppose you have data:
# Hours Studied Marks
# 1 40
# 2 50
# 3 60
# 4 70
# Linear Regression learns the pattern:
# Marks=10×Hours+30Marks=10×Hours+30
# Now if a student studies for 5 hours:
# Marks=10(5)+30=80Marks=10(5)+30=80
# So the model predicts 80 marks.
# Main Goals of Linear Regression
# 1. Prediction
# Used to predict numerical values like:
# House prices
# Salary prediction
# Temperature forecasting
# Sales prediction
# 2. Find Relationship Between Variables
# It helps understand:
# How one variable affects another
# Positive or negative impact
# Example:
# More advertising → more sales
# 3. Trend Analysis
# It identifies trends in data using a straight-line relationship.
# Formula of Linear Regression
# y=mx+by=mx+b
# Where:
# y = predicted output
# x = input feature
# m = slope (change rate)
# b = intercept
# In Machine Learning
# Linear Regression is a:
# Supervised Learning Algorithm
# Used for Regression Problems
# Works with continuous output values
# Real-Life Applications
# Stock price prediction
# Weather forecasting
# Business sales prediction
# Fraud amount estimation
# Student performance prediction
# Q2. What is the difference Between Simple LinearRegression And Multiple LinearRegression.
# Difference Between Simple Linear Regression and Multiple Linear
# Regression
# Basis Simple Linear Regression Multiple Linear Regression
# Number of Input Variables Only 1 independent variable 2 or more independent
# variables
# Purpose Predict output using one factor Predict output using multiple
# factors
# Formula y=mx+by=mx+b y=b0+b1x1+b2x2+...y=b0 +b1 x1
# +b2 x2 +...
# Complexity Simple and easy More complex
# Example Marks based on study hours Marks based on study hours,
# sleep, attendance
# Graph Straight line in 2D Plane/hyperplane in multi-
# dimensions
# 1. Simple Linear Regression
# In Simple Linear Regression:
# There is one input feature (X)
# One output variable (Y)
# Example
# Predict salary using:
# Years of experience only
# Salary=m(Experience)+bSalary=m(Experience)+b
# Dataset Example
# Experience Salary
# 1 year 20k
# 2 years 30k
# 3 years 40k
# Here:
# Input = Experience
# Output = Salary
# 2. Multiple Linear Regression
# In Multiple Linear Regression:
# There are multiple input features
# One output variable
# Example
# Predict house price using:
# Area
# Number of rooms
# Location
# Age of house
# Formula:
# y=b0+b1x1+b2x2+b3x3y=b0+b1x1+b2x2+b3x3
# Dataset Example
# Area Rooms Age Price
# 1000 2 5 20L
# 1500 3 2 35L
# Here:
# Multiple inputs affect the output
# Key Difference in One Line
# Simple Linear Regression → One input variable
# Multiple Linear Regression → Multiple input variables
# Real-Life Analogy
# Simple Linear Regression
# Marks depend only on:
# Study hours
# Multiple Linear Regression
# Marks depend on:
# Study hours
# Sleep
# Attendance
# Practice
# So Multiple Linear Regression gives more realistic predictions because many factors are considered
# together.
# Q3. What is the Best Fit Line In LinearRegression?
# Best Fit Line in Linear Regression
# The Best Fit Line is the straight line that passes through the data points in such a way that it gives
# the minimum prediction error.
# It is also called:
# Regression Line
# Line of Best Fit
# Simple Definition
# The best fit line is the line that best represents the relationship between input data (X) and output
# data (Y).
# Example
# Suppose we have data:
# Hours Studied Marks
# 1 40
# 2 50
# 3 60
# 4 70
# Linear Regression tries to draw a line that is closest to all points.
# The equation may become:
# y=10x+30y=10x+30
# Where:
# xx = study hours
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# yy = predicted marks
# 10 = slope
# 30 = intercept
# Why is it called “Best” Fit?
# Because this line minimizes the total error between:
# Actual values
# Predicted values
# The error is calculated using:
# Residuals
# Mean Squared Error (MSE)
# Residual (Error)
# Residual=Actual Value−Predicted ValueResidual=Actual Value−Predicted Value
# The best fit line tries to make all residuals as small as possible.
# Goal of Best Fit Line
# Predict future values
# Show relationship between variables
# Minimize prediction errors
# Real-Life Example
# If:
# More study hours generally increase marks
# Then the best fit line shows this trend clearly and helps predict marks for new students.
# Important Point
# The line usually does not pass through every point exactly because real-world data contains:
# Noise
# Random variations
# Outliers
# So Linear Regression finds the line that is closest to all points overall.
# Q4. What Do Slop And intershep represent in LinearRegression.?
# What do Slope and Intercept represent in Linear Regression?
# Linear Regression equation:
# y=mx+by=mx+b
# mm
# bb
# Slope and intercept sliders update the line on the graph.
# -10-8-6-4-2246810-10-5510y-interceptx-intercept
# Where:
# yy = predicted output
# xx = input variable
# mm = slope
# bb = intercept
# 1. Slope (m)
# Meaning
# Slope represents:
# How much the output changes when the input changes by 1 unit.
# It shows:
# Direction of relationship
# Rate of change
# Example
# Equation:
# y=10x+30y=10x+30
# Here:
# Slope m=10m=10
# Meaning:
# If study hours increase by 1 hour,
# Marks increase by 10 marks.
# Types of Slope
# Positive Slope
# m>0m>0
# As xx increases, yy increases.
# Example:
# More study → more marks
# Negative Slope
# m<0m<0
# As xx increases, yy decreases.
# Example:
# More speed → less travel time
# 2. Intercept (b)
# Meaning
# Intercept represents:
# The value of yy when x=0x=0.
# It is the point where the line crosses the Y-axis.
# Example
# Equation:
# y=10x+30y=10x+30
# Here:
# Intercept b=30b=30
# Meaning:
# If study hours are 0,
# Predicted marks are 30.
# Real-Life Analogy
# Suppose:
# Taxi fare starts at ₹50
# Then ₹10 per kilometer
# Equation:
# Fare=10x+50Fare=10x+50
# Where:
# 10 = slope (charge per km)
# 50 = intercept (starting charge)
# Summary Table
# Term Symbol Meaning
# Slope mm Change in output for 1-
# unit input change
# Intercept bb Output value when input
# is 0
# Q5. What Should You Use LinearRegression And When Should You Not Use
# LinearRegression. ?
# When Should You Use Linear Regression and When Should
# You NOT Use It?
# ✅
# When You Should Use Linear Regression
# Linear Regression should be used when:
# 1. Output is Continuous (Numerical)
# Use it when you want to predict values like:
# House price
# Salary
# Temperature
# Sales amount
# Examples
# Predicting student marks
# Predicting monthly profit
# Predicting fuel consumption
# 2. Relationship Between Variables is Linear
# Use Linear Regression when data follows an approximately straight-line relationship.
# Example:
# More study hours → higher marks
# 3. You Want Simple and Interpretable Models
# Linear Regression is easy to:
# Understand
# Train
# Explain
# Good for beginners and business analysis.
# 4. Small to Medium Sized Datasets
# It works well on:
# Clean datasets
# Structured/tabular data
# 5. Need Fast Training
# Linear Regression is computationally fast compared to complex ML models.
# ✅
# Real-Life Use Cases
# Problem Use Linear Regression?
# House price prediction Yes
# Sales forecasting Yes
# Salary prediction Yes
# Temperature prediction Yes
# ❌
# When You Should NOT Use Linear Regression
# 1. When Relationship is Non-Linear
# If data forms:
# Curve
# Complex pattern
# Exponential relationship
# Then Linear Regression performs poorly.
# Example
# Population growth over time.
# 2. For Classification Problems
# Linear Regression is NOT suitable when output is categories like:
# Yes/No
# Spam/Not Spam
# Fraud/Not Fraud
# Use:
# Logistic Regression
# Decision Trees
# Classification algorithms
# instead.
# 3. When Data Has Many Outliers
# Outliers strongly affect the best fit line.
# Example:
# One extremely high salary value can disturb predictions.
# 4. When Features Are Highly Correlated
# If input variables depend heavily on each other:
# Multicollinearity problem occurs
# Model becomes unstable
# 5. When Data is Very Complex
# For:
# Images
# Audio
# NLP tasks
# Deep patterns
# Use:
# Neural Networks
# Deep Learning
# Advanced ML algorithms
# Summary Table
# Situation Use Linear Regression?
# Predict continuous values ✅ Yes
# Straight-line relationship ✅ Yes
# Simple model needed ✅ Yes
# Classification problem ❌ No
# Non-linear data ❌ No
# Complex image/text data ❌ No
# One-Line Conclusion
# Use Linear Regression for simple numerical prediction problems with linear relationships, but avoid it
# for classification, highly complex, or non-linear data problems.
# Q6. What Is Difference Between Overfitting And UnderFitting . ?
# Difference Between Overfitting and Underfitting
# In Machine Learning, both Overfitting and Underfitting are problems related to model performance.
# 1. Underfitting
# Meaning
# Underfitting happens when:
# The model is too simple to learn the pattern in the data.
# The model cannot capture important relationships.
# Characteristics
# Poor performance on training data
# Poor performance on testing data
# High bias
# Low accuracy
# Example
# Suppose data is curved, but the model tries to fit only a straight line.
# Then predictions become inaccurate.
# Real-Life Analogy
# A student studies only 1 page before exam:
# Cannot understand concepts properly
# Performs badly everywhere
# Causes of Underfitting
# Model too simple
# Too little training
# Important features missing
# 2. Overfitting
# Meaning
# Overfitting happens when:
# The model learns the training data too perfectly, including noise and unnecessary details.
# It memorizes instead of learning general patterns.
# Characteristics
# Very high training accuracy
# Poor testing accuracy
# High variance
# Poor generalization
# Example
# The model tries to pass through every data point exactly.
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# It becomes too complex.
# Real-Life Analogy
# A student memorizes answers exactly:
# Performs well on same questions
# Fails on new questions
# Causes of Overfitting
# Too complex model
# Too much training
# Small dataset
# Noise in data
# Main Difference
# Feature Underfitting Overfitting
# Model Complexity Too simple Too complex
# Training Accuracy Low Very high
# Testing Accuracy Low Low
# Learns Pattern Properly? No Learns too much
# Bias High Low
# Variance Low High
# Visualization Idea
# Underfitting
# Straight line on curved data
# Good Fit
# Captures main pattern correctly
# Overfitting
# Zig-zag line touching every point
# How to Prevent Them
# Prevent Underfitting
# Increase model complexity
# Add more features
# Train longer
# Prevent Overfitting
# Use more data
# Feature selection
# Cross-validation
# Regularization
# Simpler model
# One-Line Conclusion
# Underfitting means the model learns too little, while Overfitting means the model learns too much
# from the training data.
# Q7. What Do You Mean By Regulrize technique . ?
# What Do You Mean by Regularization Technique?
# Regularization is a technique used in Machine Learning to:
# Reduce Overfitting and improve model generalization.
# It helps the model learn important patterns without memorizing the training data.
# Simple Meaning
# Sometimes a model becomes:
# Too complex
# Too sensitive to training data
# Regularization adds a penalty to the model so it stays simpler and more stable.
# Main Goal of Regularization
# ✅ Prevent Overfitting
# ✅ Improve prediction on new data
# ✅ Reduce model complexity
# How Regularization Works
# It adds a penalty term to the loss function.
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Basic Linear Regression cost function:
# Cost=ErrorCost=Error
# With Regularization:
# Cost=Error+PenaltyCost=Error+Penalty
# The penalty discourages very large weights.
# Types of Regularization
# 1. L1 Regularization (Lasso Regression)
# Penalty uses absolute values of coefficients.
# ∑∣w∣∑∣w∣
# Features
# Can make some coefficients exactly 0
# Performs feature selection
# Produces sparse models
# 2. L2 Regularization (Ridge Regression)
# Penalty uses squared values of coefficients.
# ∑w2∑w2
# Features
# Reduces coefficient size
# Does not make them exactly zero
# Most commonly used
# 3. Elastic Net
# Combination of:
# L1 + L2 Regularization
# Used when:
# Dataset has many features
# Features are correlated
# Why Regularization is Important
# Without regularization:
# Model may memorize noise
# Poor testing accuracy
# With regularization:
# Model becomes balanced
# Better generalization
# Real-Life Analogy
# Suppose a student:
# Memorizes every question answer exactly → Overfitting
# Regularization is like:
# Teaching the student to understand concepts instead of memorizing everything.
# Example
# Imagine predicting house price using many unnecessary features.
# Without regularization:
# Model may give huge importance to irrelevant features.
# With regularization:
# Important features get priority
# Unnecessary features get reduced impact
# Summary Table
# Technique Penalty Type Special Feature
# L1 (Lasso) Absolute values Feature selection
# L2 (Ridge) Squared values Reduces large weights
# Elastic Net Combination Handles correlated
# features
# One-Line Conclusion
# Regularization is a technique used to reduce overfitting by adding a penalty to the model’s complexity
# so that it performs better on new unseen data.
# Q8. What Is Difference between Rige , Lasso , Elasticnt. ?
# Difference Between Ridge Regression, Lasso Regression, and
# Elastic Net
# All three are Regularization techniques used to reduce:
# Overfitting
# Model complexity
# They are mainly used with Linear Regression models.
# 1. Ridge Regression (L2 Regularization)
# Meaning
# Ridge adds penalty using:
# Square of coefficients
# Formula:
# Loss+λ∑w2Loss+λ∑w2
# Features
# ✅ Reduces large coefficient values
# ✅ Keeps all features
# ✅ Prevents overfitting
# Important Point
# Coefficients become small
# But never exactly 0
# Best Use Case
# Use Ridge when:
# Most features are useful
# Multicollinearity exists
# 2. Lasso Regression (L1 Regularization)
# Meaning
# Lasso adds penalty using:
# Absolute value of coefficients
# Formula:
# Loss+λ∑∣w∣Loss+λ∑∣w∣
# Features
# ✅ Can make coefficients exactly 0
# ✅ Performs feature selection
# ✅ Removes unimportant features
# Best Use Case
# Use Lasso when:
# Dataset has many unnecessary features
# Feature selection is needed
# 3. Elastic Net
# Meaning
# Elastic Net combines:
# Ridge + Lasso
# Formula:
# Loss+λ1∑∣w∣+λ2∑w2Loss+λ1∑∣w∣+λ2∑w2
# Features
# ✅ Combines benefits of both
# ✅ Handles correlated features well
# ✅ Performs feature selection + coefficient shrinking
# Best Use Case
# Use Elastic Net when:
# Many features exist
# Features are correlated
# Need balanced regularization
# Main Differences
# Feature Ridge Lasso Elastic Net
# Regularization Type L2 L1 L1 + L2
# Penalty Squared weights Absolute weights Combination
# Feature Selection ❌ No ✅ Yes ✅ Yes
# Coefficients ❌ No ✅ Yes ✅ Sometimes
# Become Zero
# Handles ✅ Good Moderate ✅ Best
# Multicollinearity
# Model Complexity Medium High Balanced
# Reduction
# Simple Analogy
# Suppose 10 students work on a project.
# Ridge
# Keeps all students
# Reduces contribution of weak students
# Lasso
# Removes weak students completely
# Elastic Net
# Removes some weak students
# Reduces contribution of others
# One-Line Conclusion
# Ridge shrinks coefficients, Lasso removes unnecessary features, and Elastic Net combines both
# techniques for balanced regularization.
