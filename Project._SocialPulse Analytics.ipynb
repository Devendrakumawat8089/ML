# %%
print("Project Work")
# Out:
# Project Work

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# # Task 1: Data Understanding & Cleaning

# %% [markdown]
# Load dataset, check shape, data types, missing values and duplicates.

# %%
# Load Data_Set

df = pd.read_csv("social_media_user_behavior.csv")
df.head(2)
# Out:
#       user_id  age age_group             gender         country  \
# 0  USR-000001   22     18-24         Non-Binary     Philippines
# 1  USR-000002   31     25-34  Prefer Not to Say  United Kingdom
#
#                occupation        education_level income_bracket  \
# 0        Teacher/Educator  Doctoral/Professional    $100K-$150K
# 1  Marketing Professional   High School or Below      $50K-$75K
#
#   relationship_status primary_platform  ...  productivity_impact  \
# 0             Married         Facebook  ...            No Change
# 1   In a Relationship           TikTok  ...            No Change
#
#    platform_satisfaction  account_created_date  account_age_years  \
# 0           Dissatisfied            2025-05-14                0.9
# 1           Dissatisfied            2019-07-18                6.7
#
#   is_verified_account is_content_creator uses_ai_features  \
# 0               False              False            False
# ...

# %% [markdown]
# To Check The Shape(row , Columns)

# %%
df.shape
# Out:
# (25000, 45)

# %% [markdown]
# To Check Data Types

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 45 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   user_id                             25000 non-null  str
#  1   age                                 25000 non-null  int64
#  2   age_group                           25000 non-null  str
#  3   gender                              25000 non-null  str
#  4   country                             25000 non-null  str
#  5   occupation                          25000 non-null  str
#  6   education_level                     25000 non-null  str
#  7   income_bracket                      25000 non-null  str
#  8   relationship_status                 25000 non-null  str
#  9   primary_platform                    25000 non-null  str
#  10  num_platforms_used                  25000 non-null  int64
#  11  daily_screen_time_minutes           25000 non-null  int64
# ...

# %% [markdown]
# Missing Values And Duplicates

# %%
df.isnull().sum()
# Out:
# user_id                               0
# age                                   0
# age_group                             0
# gender                                0
# country                               0
# occupation                            0
# education_level                       0
# income_bracket                        0
# relationship_status                   0
# primary_platform                      0
# num_platforms_used                    0
# daily_screen_time_minutes             0
# weekly_sessions                       0
# avg_session_duration_minutes          0
# preferred_content_type                0
# primary_device                        0
# usage_purpose                         0
# posts_per_week                        0
# likes_per_day                         0
# comments_per_day                      0
# shares_per_week                       0
# followers_count                       0
# following_count                       0
# ...

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# # Task 2: Data Preprocessing

# %% [markdown]
# Apply Standardization, Normalization and Encoding.

# %% [markdown]
# Apply Standardization

# %%
df1 = pd.read_csv("social_media_user_behavior.csv")

df1.head(2)
# Out:
#       user_id  age age_group             gender         country  \
# 0  USR-000001   22     18-24         Non-Binary     Philippines
# 1  USR-000002   31     25-34  Prefer Not to Say  United Kingdom
#
#                occupation        education_level income_bracket  \
# 0        Teacher/Educator  Doctoral/Professional    $100K-$150K
# 1  Marketing Professional   High School or Below      $50K-$75K
#
#   relationship_status primary_platform  ...  productivity_impact  \
# 0             Married         Facebook  ...            No Change
# 1   In a Relationship           TikTok  ...            No Change
#
#    platform_satisfaction  account_created_date  account_age_years  \
# 0           Dissatisfied            2025-05-14                0.9
# 1           Dissatisfied            2019-07-18                6.7
#
#   is_verified_account is_content_creator uses_ai_features  \
# 0               False              False            False
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df1 = df1.dropna()

# %%
df1
# Out:
#           user_id  age age_group             gender         country  \
# 0      USR-000001   22     18-24         Non-Binary     Philippines
# 1      USR-000002   31     25-34  Prefer Not to Say  United Kingdom
# 2      USR-000003   21     18-24             Female             UAE
# 3      USR-000004   33     25-34             Female    Saudi Arabia
# 4      USR-000005   23     18-24             Female          Poland
# ...           ...  ...       ...                ...             ...
# 24995  USR-024996   26     25-34               Male      Bangladesh
# 24996  USR-024997   29     25-34               Male           Japan
# 24997  USR-024998   30     25-34             Female           Chile
# 24998  USR-024999   23     18-24             Female           India
# 24999  USR-025000   39     35-44             Female       Argentina
#
#                        occupation        education_level income_bracket  \
# 0                Teacher/Educator  Doctoral/Professional    $100K-$150K
# ...

# %% [markdown]
# Categorical To Numerical

# %%
df1['productivity_impact'] = lb.fit_transform(df['productivity_impact'])
df1['primary_platform'] = lb.fit_transform(df1['primary_platform'])
df1['platform_satisfaction'] = lb.fit_transform(df1['platform_satisfaction'])
df1['relationship_status'] = lb.fit_transform(df1['relationship_status'])
df1['account_created_date'] = lb.fit_transform(df1['account_created_date'])
df1['income_bracket'] = lb.fit_transform(df1['income_bracket'])
df1['is_verified_account'] = lb.fit_transform(df1['is_verified_account'])
df1['education_level'] = lb.fit_transform(df1['education_level'])
df1['is_content_creator'] = lb.fit_transform(df1['is_content_creator'])
df1['occupation'] = lb.fit_transform(df1['occupation'])
df1['uses_ai_features'] = lb.fit_transform(df1['uses_ai_features'])
df1['country'] = lb.fit_transform(df1['country'])
df1['checks_phone_first_morning'] = lb.fit_transform(df1['checks_phone_first_morning'])
df1['gender'] = lb.fit_transform(df1['gender'])
df1['uses_screen_time_limits'] = lb.fit_transform(df1['uses_screen_time_limits'])
df1['age_group'] = lb.fit_transform(df1['age_group'])
df1['account_age_years'] = lb.fit_transform(df1['account_age_years'])
df1['user_id'] = lb.fit_transform(df1['user_id'])
df1['engagement_rate_pct'] = lb.fit_transform(df1['engagement_rate_pct'])

# %%
df1.columns
# Out:
# Index(['user_id', 'age', 'age_group', 'gender', 'country', 'occupation',
#        'education_level', 'income_bracket', 'relationship_status',
#        'primary_platform', 'num_platforms_used', 'daily_screen_time_minutes',
#        'weekly_sessions', 'avg_session_duration_minutes',
#        'preferred_content_type', 'primary_device', 'usage_purpose',
#        'posts_per_week', 'likes_per_day', 'comments_per_day',
#        'shares_per_week', 'followers_count', 'following_count',
#        'engagement_rate_pct', 'video_consumption_daily_minutes',
#        'has_purchased_via_social', 'follows_influencers', 'ad_click_frequency',
#        'monthly_social_spending_usd', 'uses_privacy_settings',
#        'experienced_cyberbullying', 'reports_fake_news_frequency',
#        'self_reported_mental_health_effect', 'sleep_hours_per_night',
#        'addiction_level_1_to_10', 'productivity_impact',
#        'platform_satisfaction', 'account_created_date', 'account_age_years',
# ...

# %%
df['gender'].value_counts()
# Out:
# gender
# Female               11930
# Male                 11574
# Non-Binary            1009
# Prefer Not to Say      487
# Name: count, dtype: int64

# %%
print(df['age'].mean())
# Out:
# 34.68384

# %%
df1['engagement_rate_pct'].value_counts()
# Out:
# engagement_rate_pct
# 0      1895
# 172     138
# 193     131
# 165     129
# 203     124
#        ...
# 553       1
# 539       1
# 486       1
# 541       1
# 535       1
# Name: count, Length: 556, dtype: int64

# %%
x = df1.drop(columns= ['country'])
y = df1['country']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
x_train_sc = sc.fit_transform(x_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 x_train_sc = sc.fit_transform(x_train)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:907, in TransformerMixin.fit_transform(self, X, y, **fit_params)
# ...

# %%
x_train_new = pd.DataFrame(x_train_sc , columns=x_train.columns)
