# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('mussorie_hotels_data.csv')
df.head()
# Out:
#                                         hotel_name  rating  review_count  \
# 0                   HOTEL THE PINE VILLA MUSSOORIE     4.7           176
# 1                   The Leo Hotels Mokshada Suites     4.4           175
# 2  Welcomhotel By ITC Hotels, The Savoy, Mussoorie     4.8         12032
# 3  JW Marriott Mussoorie Walnut Grove Resort & Spa     4.5          6475
# 4                                Mussoorie Gateway     4.2          1780
#
#   hotel_category  price_inr   amenity_1     amenity_2       amenity_3  \
# 0   3-star hotel       2223         NaN           NaN             NaN
# 1            NaN       2135        Pool  Free parking  Free breakfast
# 2   5-star hotel      27600        Pool           Spa    Free parking
# 3   5-star hotel      33000        Pool           Spa    Free parking
# 4   3-star hotel       3264  Free Wi-Fi     Breakfast           Wi-Fi
#
#         amenity_4                              description deal_label  \
# 0             NaN                                      NaN        NaN
# 1      Free Wi-Fi                                      NaN        NaN
# 2  Free breakfast  Refined country house escape with a spa        NaN
# 3  Free breakfast    Luxe hotel with 4 restaurants & a spa        NaN
# 4         Parking        Laid-back hotel with valley views        NaN
#
#    discount_percent
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
df.isnull().sum()
# Out:
# hotel_name           0
# rating               0
# review_count         0
# hotel_category       1
# price_inr            0
# amenity_1           11
# amenity_2           11
# amenity_3           12
# amenity_4           14
# description         59
# deal_label          87
# discount_percent    87
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df["rating"] = pd.to_numeric(df["rating"], errors="coerce")

# %%
df["review_count"] = pd.to_numeric(df["review_count"], errors="coerce")

# %%
df["price_inr"] = pd.to_numeric(df["price_inr"], errors="coerce")

# %%
df["discount_percent"] = pd.to_numeric(df["discount_percent"], errors="coerce")

# %%
df["hotel_name"] = df["hotel_name"].str.strip()

# %%
df["hotel_category"] = df["hotel_category"].str.strip()

# %%
df["description"] = df["description"].str.strip()

# %%
df.isnull().sum()
# Out:
# hotel_name           0
# rating               0
# review_count         0
# hotel_category       1
# price_inr            0
# amenity_1           11
# amenity_2           11
# amenity_3           12
# amenity_4           14
# description         59
# deal_label          87
# discount_percent    87
# dtype: int64

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 5 entries, 5 to 37
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   hotel_name        5 non-null      str
#  1   rating            5 non-null      float64
#  2   review_count      5 non-null      int64
#  3   hotel_category    5 non-null      str
#  4   price_inr         5 non-null      int64
#  5   amenity_1         5 non-null      str
#  6   amenity_2         5 non-null      str
#  7   amenity_3         5 non-null      str
#  8   amenity_4         5 non-null      str
#  9   description       5 non-null      str
#  10  deal_label        5 non-null      str
#  11  discount_percent  5 non-null      float64
# dtypes: float64(2), int64(2), str(8)
# memory usage: 520.0 bytes
